# %% [markdown]
# <a href="https://colab.research.google.com/github/hypnagonia/colabs/blob/main/OpenRank_%2B_Agora_City.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openrank-sdk

from google.colab import auth
from openrank_sdk import EigenTrust
import pandas

auth.authenticate_user()
a = EigenTrust()

# %% [markdown]
# ## LocalTrust

# %%
import requests

base_url = 'https://base-sepolia.easscan.org/attestations/forSchema/0x5ee00c7a6606190e090ea17749ec77fe23338387c23c0643c4251380f37eebc3?_data=routes%2F__boundary%2Fattestations%2FforSchema%2F%24schemaUID&limit=50'

def get_attestations(page=1):
    results = []

    def run(page):
        nonlocal results
        url = base_url
        if page > 1:
            url += f'&page={page}'

        res = requests.get(url).json()
        results.extend(res['attestations'])

        if len(results) < res['totalAttestationCount']:
            return run(page + 1)

        return results

    return run(page)

attestations = get_attestations()
localtrust = [{'i': r['attester'], 'j': r['recipient'], 'v': 1 } for r in attestations if r['attester'] != r['recipient']]
df = pandas.DataFrame(localtrust)
df
# Out:
#                                              i  \
# 0   0x02a72042AF3Af336f4D0b465881CD0174A1dBa33
# 1   0x02a72042AF3Af336f4D0b465881CD0174A1dBa33
# 2   0x02a72042AF3Af336f4D0b465881CD0174A1dBa33
# 3   0x662CA97f4Ab71fEc6964e1E751E2B3c967F7a47C
# 4   0x02a72042AF3Af336f4D0b465881CD0174A1dBa33
# ..                                         ...
# 84  0x8F6a4aA5CdE7B78f28732a5d811198D79d9B4de4
# 85  0x8F6a4aA5CdE7B78f28732a5d811198D79d9B4de4
# 86  0x8F6a4aA5CdE7B78f28732a5d811198D79d9B4de4
# 87  0x8F6a4aA5CdE7B78f28732a5d811198D79d9B4de4
# 88  0xb97214755c216B482A298Aec26075dcd7bCEFB86
#
#                                              j  v
# 0   0x9FC3B33884e1D056a8CA979833d686abD267f9f8  1
# 1   0x662CA97f4Ab71fEc6964e1E751E2B3c967F7a47C  1
# 2   0x596A93Db265dd748Fe5c75E606ADfF3ea34f61d1  1
# 3   0x9FC3B33884e1D056a8CA979833d686abD267f9f8  1
# 4   0x9FC3B33884e1D056a8CA979833d686abD267f9f8  1
# ..                                         ... ..
# ...

# %% [markdown]
# ##EigenTrust

# %%
scores = a.run_eigentrust(localtrust)
df2 = pandas.DataFrame(scores)
df2
# Out:
#                                             i         v
# 0  0x9FC3B33884e1D056a8CA979833d686abD267f9f8  0.107112
# 1  0x02a72042AF3Af336f4D0b465881CD0174A1dBa33  0.106148
# 2  0x55795567D4E13FCAf30515fd6E0d93f62c297557  0.090870
# 3  0x596A93Db265dd748Fe5c75E606ADfF3ea34f61d1  0.062475
# 4  0x662CA97f4Ab71fEc6964e1E751E2B3c967F7a47C  0.061795
# 5  0xb97214755c216B482A298Aec26075dcd7bCEFB86  0.060580
# 6  0x8F6a4aA5CdE7B78f28732a5d811198D79d9B4de4  0.059899
# 7  0x265e788a6D0b54216Be125B0e82f5f7F2DB0C961  0.059899
# 8  0x66f77aC6aeb4CA86b7C74fE6c634fA2e294a9661  0.059899
# 9  0xd940b1bDD9534fbFE5B05023Da44f9Cc308a266f  0.059899

# %% [markdown]
# ## Download results as CSV

# %%
from google.colab import files

csv_file_path = '/content/openrank_agoracity_v0.csv'
df2.to_csv(csv_file_path, index=False)
files.download(csv_file_path)
